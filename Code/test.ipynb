# %%
import os
import logging
import time
import requests
from urllib.parse import urljoin, unquote
from bs4 import BeautifulSoup
import psycopg2
from psycopg2 import OperationalError, Error
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Constants
BASE_URL = 'https://emalls.ir/'
PAGES = range(1, 11)
REQUEST_DELAY = 1  # seconds

# Configure root logger
def configure_root_logger():
    logger = logging.getLogger(__name__)
    if not logger.handlers:
        logging.basicConfig(level=logging.INFO,
                            format='%(asctime)s %(levelname)s: %(message)s')
    return logger

logger = configure_root_logger()

# Configure failed-shops logger (writes to failed_shops.log)
failed_logger = logging.getLogger('failed_shops')
if not failed_logger.handlers:
    failed_logger.setLevel(logging.INFO)
    fh = logging.FileHandler('failed_shops.log', encoding='utf-8')
    fh.setFormatter(logging.Formatter('%(asctime)s %(message)s'))
    failed_logger.addHandler(fh)

# Database configuration
DB_CONFIG = {
    'dbname':   os.environ['EMALLS_DB'],
    'user':     os.environ['EMALLS_USER'],
    'password': os.environ['EMALLS_PW'],
    'host':     os.environ['EMALLS_HOST'],
    'port':     os.environ['EMALLS_PORT'],
}

# Utility functions
def table_exists(conn, name):
    """
    Check if a table exists in the public schema.
    Returns True if exists, False otherwise.
    """
    try:
        with conn.cursor() as cur:
            cur.execute(
                """
                SELECT EXISTS (
                  SELECT 1 FROM information_schema.tables
                  WHERE table_schema='public' AND table_name=%s
                );
                """, (name,)
            )
            return cur.fetchone()[0]
    except Error as e:
        logger.error(f"[table_exists] Error checking table '{name}': {e}")
        return False


def init_db(conn):
    """
    Initialize the database by creating the emalls_shops table if missing.
    """
    try:
        with conn.cursor() as cur:
            cur.execute(
                """
                CREATE TABLE IF NOT EXISTS emalls_shops (
                  id          SERIAL PRIMARY KEY,
                  source      TEXT    NOT NULL,
                  is_assigned BOOLEAN NOT NULL,
                  domain      TEXT UNIQUE,
                  emalls_id   TEXT,
                  address     TEXT,
                  tel         TEXT[],
                  owner       TEXT,
                  category    TEXT[]
                );
                """
            )
        conn.commit()
        logger.info("Database schema ensured")
    except Error as e:
        logger.error(f"[init_db] Error initializing schema: {e}")
        conn.rollback()


def insert_shop(conn, info):
    """
    Insert or update a shop record, returning the record ID.
    """
    try:
        with conn.cursor() as cur:
            cur.execute(
                """
                INSERT INTO emalls_shops
                  (source, is_assigned, domain, emalls_id, address, tel, owner, category)
                VALUES (%(source)s, %(is_assigned)s, %(domain)s, %(emalls_id)s,
                        %(address)s, %(tel)s, %(owner)s, %(category)s)
                ON CONFLICT (domain) DO UPDATE
                  SET source      = EXCLUDED.source,
                      is_assigned = EXCLUDED.is_assigned,
                      emalls_id   = EXCLUDED.emalls_id,
                      address     = EXCLUDED.address,
                      tel         = EXCLUDED.tel,
                      owner       = EXCLUDED.owner,
                      category    = EXCLUDED.category
                RETURNING id;
                """, info
            )
            row = cur.fetchone()
        conn.commit()
        return row[0] if row else None
    except Error as e:
        logger.error(f"[insert_shop] DB error for '{info.get('domain')}': {e}")
        conn.rollback()
        return None


def extract_shop_info(soup, shop_url):
    """
    Extract key info from a shop page soup.
    Returns dict with defaults: empty strings or lists.
    """
    info = {
        'source':      'emalls',
        'is_assigned': False,
        'domain':      '',
        'emalls_id':   shop_url,
        'address':     '',
        'tel':         [],
        'owner':       '',
        'category':    [],
    }
    # 1) Website URL
    tag = soup.find(id="ContentPlaceHolder1_HlkWebsite2")
    if tag and tag.has_attr('href'):
        info['domain'] = tag['href'].strip()

    # 2) Address
    tag = soup.find(id="ContentPlaceHolder1_lblAddress2")
    if tag:
        info['address'] = tag.get_text(strip=True)

    # 3) Telephone(s)
    tag = soup.find(id="ContentPlaceHolder1_HlkTelephone2")
    if tag and tag.has_attr('href'):
        raw = tag['href'].split(':', 1)[-1]
        decoded = unquote(raw)
        parts = [p.strip() for p in decoded.split('،') if p.strip()]
        info['tel'] = parts

    # 4) Owner
    tag = soup.find(id="ContentPlaceHolder1_lblMasool2")
    if tag:
        info['owner'] = tag.get_text(strip=True)

    # 5) Categories (max 5)
    container = soup.find(id="DivPartProducts")
    if container:
        titles = container.select('.shopcat-box .title')[:5]
        cats = [t.get_text(strip=True) for t in titles if t.get_text(strip=True)]
        info['category'] = cats or []

    return info


def main():
    logger.info("Starting scraper")
    # Connect to database
    try:
        conn = psycopg2.connect(**DB_CONFIG)
    except OperationalError as e:
        logger.error(f"DB connection failed: {e}")
        return

    # Ensure table exists
    if not table_exists(conn, 'emalls_shops'):
        init_db(conn)
    
    # Fetch existing shop IDs
    with conn.cursor() as cur:
        cur.execute("SELECT emalls_id FROM emalls_shops;")
        urls_in_db = {r[0] for r in cur.fetchall()}

    shop_urls = []

    # Crawl list pages
    with requests.Session() as session:
        session.headers.update({'User-Agent': 'Mozilla/5.0'})
        for i in PAGES:
            page_url = f"{BASE_URL}Shops/page.{i}/"
            logger.info(f"Fetching list page: {page_url}")
            try:
                r = session.get(page_url, timeout=5)
            except requests.exceptions.RequestException as e:
                logger.error(f"List page request failed: {e}")
                failed_logger.info(page_url)
                continue

            if not r.ok:
                logger.error(f"List page returned {r.status_code}")
                failed_logger.info(page_url)
                continue

            soup = BeautifulSoup(r.text, 'html.parser')
            for a in soup.select('div.shop a.shop-ax'):
                href = a.get('href')
                if href:
                    shop_urls.append(urljoin(BASE_URL, href))

            time.sleep(REQUEST_DELAY)

        # Process each shop
        for shop_url in shop_urls:
            if shop_url in urls_in_db:
                logger.info(f"Skipping already-seen shop: {shop_url}")
                continue

            logger.info(f"Processing shop: {shop_url}")
            try:
                r = session.get(shop_url, timeout=5)
            except requests.exceptions.RequestException as e:
                logger.error(f"Shop page request failed: {e}")
                failed_logger.info(shop_url)
                continue

            if not r.ok:
                logger.error(f"Shop page returned {r.status_code}")
                failed_logger.info(shop_url)
                continue

            soup = BeautifulSoup(r.text, 'html.parser')
            info = extract_shop_info(soup, shop_url)
            shop_id = insert_shop(conn, info)
            if not shop_id:
                failed_logger.info(shop_url)
                logger.warning(f"Failed to save shop: {shop_url}")
            else:
                logger.info(f"Saved shop id={shop_id}")

            time.sleep(REQUEST_DELAY)

    # Cleanup
    conn.close()
    logger.info("Scraping complete")

if __name__ == '__main__':
    main()
# Out:
# 2025-05-01 13:52:03,453 INFO: Starting scraper
# 2025-05-01 13:52:03,512 INFO: Database schema ensured
# 2025-05-01 13:52:03,515 INFO: Fetching list page: https://emalls.ir/Shops/page.1/
# 2025-05-01 13:52:06,414 INFO: Fetching list page: https://emalls.ir/Shops/page.2/
# 2025-05-01 13:52:08,340 INFO: Fetching list page: https://emalls.ir/Shops/page.3/
# 2025-05-01 13:52:10,466 INFO: Fetching list page: https://emalls.ir/Shops/page.4/
# 2025-05-01 13:52:12,370 INFO: Fetching list page: https://emalls.ir/Shops/page.5/
# 2025-05-01 13:52:15,223 INFO: Fetching list page: https://emalls.ir/Shops/page.6/
# 2025-05-01 13:52:17,602 INFO: Fetching list page: https://emalls.ir/Shops/page.7/
# 2025-05-01 13:52:19,384 INFO: Fetching list page: https://emalls.ir/Shops/page.8/
# 2025-05-01 13:52:22,011 INFO: Fetching list page: https://emalls.ir/Shops/page.9/
# 2025-05-01 13:52:25,373 INFO: Fetching list page: https://emalls.ir/Shops/page.10/
# 2025-05-01 13:52:27,447 INFO: Processing shop: https://emalls.ir/Shop/954/
# 2025-05-01 13:52:29,031 INFO: Saved shop id=1
# 2025-05-01 13:52:30,032 INFO: Processing shop: https://emalls.ir/Shop/1/
# 2025-05-01 13:52:31,358 INFO: Saved shop id=2
# 2025-05-01 13:52:32,360 INFO: Processing shop: https://emalls.ir/Shop/38988/
# 2025-05-01 13:52:32,945 INFO: Saved shop id=3
# 2025-05-01 13:52:33,946 INFO: Processing shop: https://emalls.ir/Shop/48786/
# 2025-05-01 13:52:38,957 ERROR: Shop page request failed: HTTPSConnectionPool(host='emalls.ir', port=443): Read timed out. (read timeout=5)
# 2025-05-01 13:52:38,959 INFO: https://emalls.ir/Shop/48786/
# 2025-05-01 13:52:38,961 INFO: Processing shop: https://emalls.ir/Shop/2292/
# 2025-05-01 13:52:46,215 INFO: Saved shop id=4
# 2025-05-01 13:52:47,216 INFO: Processing shop: https://emalls.ir/Shop/493/
# 2025-05-01 13:52:47,907 INFO: Saved shop id=5
# 2025-05-01 13:52:48,908 INFO: Processing shop: https://emalls.ir/Shop/51914/
# 2025-05-01 13:52:50,973 INFO: Saved shop id=6
# 2025-05-01 13:52:51,974 INFO: Processing shop: https://emalls.ir/Shop/1760/
# 2025-05-01 13:52:53,042 INFO: Saved shop id=7
# 2025-05-01 13:52:54,043 INFO: Processing shop: https://emalls.ir/Shop/29748/
# 2025-05-01 13:52:55,622 INFO: Saved shop id=8
# 2025-05-01 13:52:56,624 INFO: Processing shop: https://emalls.ir/Shop/52232/
# 2025-05-01 13:52:58,061 INFO: Saved shop id=9
# 2025-05-01 13:52:59,063 INFO: Processing shop: https://emalls.ir/Shop/577/
# 2025-05-01 13:53:00,953 INFO: Saved shop id=10
# 2025-05-01 13:53:01,954 INFO: Processing shop: https://emalls.ir/Shop/3475/
# 2025-05-01 13:53:05,212 INFO: Saved shop id=11
# 2025-05-01 13:53:06,213 INFO: Processing shop: https://emalls.ir/Shop/5460/
# 2025-05-01 13:53:08,410 INFO: Saved shop id=12
# 2025-05-01 13:53:09,412 INFO: Processing shop: https://emalls.ir/Shop/754/
# 2025-05-01 13:53:11,555 INFO: Saved shop id=13
# 2025-05-01 13:53:12,556 INFO: Processing shop: https://emalls.ir/Shop/20322/
# 2025-05-01 13:53:14,726 INFO: Saved shop id=14
# 2025-05-01 13:53:15,728 INFO: Processing shop: https://emalls.ir/Shop/593/
# 2025-05-01 13:53:18,935 INFO: Saved shop id=15
# 2025-05-01 13:53:19,936 INFO: Processing shop: https://emalls.ir/Shop/5395/
# 2025-05-01 13:53:22,604 INFO: Saved shop id=16
# 2025-05-01 13:53:23,605 INFO: Processing shop: https://emalls.ir/Shop/1000/
# 2025-05-01 13:53:26,087 INFO: Saved shop id=17
# 2025-05-01 13:53:27,088 INFO: Processing shop: https://emalls.ir/Shop/5008/
# 2025-05-01 13:53:29,024 INFO: Saved shop id=18
# 2025-05-01 13:53:30,025 INFO: Processing shop: https://emalls.ir/Shop/35316/
# 2025-05-01 13:53:32,492 INFO: Saved shop id=19
# 2025-05-01 13:53:33,494 INFO: Processing shop: https://emalls.ir/Shop/5188/
# 2025-05-01 13:53:35,810 INFO: Saved shop id=20
# 2025-05-01 13:53:36,811 INFO: Processing shop: https://emalls.ir/Shop/1931/
# 2025-05-01 13:53:37,803 INFO: Saved shop id=21
# 2025-05-01 13:53:38,805 INFO: Processing shop: https://emalls.ir/Shop/439/
# 2025-05-01 13:53:40,093 INFO: Saved shop id=22
# 2025-05-01 13:53:41,094 INFO: Processing shop: https://emalls.ir/Shop/27863/
# 2025-05-01 13:53:42,929 INFO: Saved shop id=23
# 2025-05-01 13:53:43,931 INFO: Processing shop: https://emalls.ir/Shop/2894/
# 2025-05-01 13:53:46,550 INFO: Saved shop id=24
# 2025-05-01 13:53:47,551 INFO: Processing shop: https://emalls.ir/Shop/21572/
# 2025-05-01 13:53:49,507 INFO: Saved shop id=25
# 2025-05-01 13:53:50,508 INFO: Processing shop: https://emalls.ir/Shop/172/
# 2025-05-01 13:53:52,032 INFO: Saved shop id=26
# 2025-05-01 13:53:53,033 INFO: Processing shop: https://emalls.ir/Shop/3725/
# 2025-05-01 13:53:54,032 INFO: Saved shop id=27
# 2025-05-01 13:53:55,034 INFO: Processing shop: https://emalls.ir/Shop/1593/
# 2025-05-01 13:53:57,089 INFO: Saved shop id=28
# 2025-05-01 13:53:58,090 INFO: Processing shop: https://emalls.ir/Shop/30005/
# 2025-05-01 13:53:59,766 INFO: Saved shop id=29
# 2025-05-01 13:54:00,767 INFO: Processing shop: https://emalls.ir/Shop/3395/
# 2025-05-01 13:54:02,284 INFO: Saved shop id=30
# 2025-05-01 13:54:03,285 INFO: Processing shop: https://emalls.ir/Shop/20964/
# 2025-05-01 13:54:03,894 INFO: Saved shop id=31
# 2025-05-01 13:54:04,895 INFO: Processing shop: https://emalls.ir/Shop/1615/
# 2025-05-01 13:54:06,426 INFO: Saved shop id=32
# 2025-05-01 13:54:07,427 INFO: Processing shop: https://emalls.ir/Shop/21766/
# 2025-05-01 13:54:09,870 INFO: Saved shop id=33
# 2025-05-01 13:54:10,872 INFO: Processing shop: https://emalls.ir/Shop/2424/
# 2025-05-01 13:54:12,398 INFO: Saved shop id=34
# 2025-05-01 13:54:13,400 INFO: Processing shop: https://emalls.ir/Shop/355/
# 2025-05-01 13:54:16,245 INFO: Saved shop id=35
# 2025-05-01 13:54:17,246 INFO: Processing shop: https://emalls.ir/Shop/5292/
# 2025-05-01 13:54:18,983 INFO: Saved shop id=36
# 2025-05-01 13:54:19,984 INFO: Processing shop: https://emalls.ir/Shop/1065/
# 2025-05-01 13:54:23,781 INFO: Saved shop id=37
# 2025-05-01 13:54:24,782 INFO: Processing shop: https://emalls.ir/Shop/3009/
# 2025-05-01 13:54:25,898 INFO: Saved shop id=38
# 2025-05-01 13:54:26,899 INFO: Processing shop: https://emalls.ir/Shop/32679/
# 2025-05-01 13:54:29,460 INFO: Saved shop id=39
# 2025-05-01 13:54:30,461 INFO: Processing shop: https://emalls.ir/Shop/31776/
# 2025-05-01 13:54:33,346 INFO: Saved shop id=40
# 2025-05-01 13:54:34,347 INFO: Processing shop: https://emalls.ir/Shop/42864/
# 2025-05-01 13:54:35,241 INFO: Saved shop id=41
# 2025-05-01 13:54:36,242 INFO: Processing shop: https://emalls.ir/Shop/26794/
# 2025-05-01 13:54:37,111 INFO: Saved shop id=42
# 2025-05-01 13:54:38,112 INFO: Processing shop: https://emalls.ir/Shop/397/
# 2025-05-01 13:54:39,339 INFO: Saved shop id=43
# 2025-05-01 13:54:40,341 INFO: Processing shop: https://emalls.ir/Shop/18284/
# 2025-05-01 13:54:41,355 INFO: Saved shop id=44
# 2025-05-01 13:54:42,357 INFO: Processing shop: https://emalls.ir/Shop/3811/
# 2025-05-01 13:54:45,083 INFO: Saved shop id=45
# 2025-05-01 13:54:46,084 INFO: Processing shop: https://emalls.ir/Shop/17/
# 2025-05-01 13:54:47,838 INFO: Saved shop id=46
# 2025-05-01 13:54:48,840 INFO: Processing shop: https://emalls.ir/Shop/20269/
# 2025-05-01 13:54:50,871 INFO: Saved shop id=47
# 2025-05-01 13:54:51,872 INFO: Processing shop: https://emalls.ir/Shop/6986/
# 2025-05-01 13:54:52,551 INFO: Saved shop id=48
# 2025-05-01 13:54:53,552 INFO: Processing shop: https://emalls.ir/Shop/306/
# 2025-05-01 13:54:55,835 INFO: Saved shop id=49
# 2025-05-01 13:54:56,836 INFO: Processing shop: https://emalls.ir/Shop/38562/
# 2025-05-01 13:54:59,035 INFO: Saved shop id=50
# 2025-05-01 13:55:00,036 INFO: Processing shop: https://emalls.ir/Shop/21548/
# 2025-05-01 13:55:03,441 INFO: Saved shop id=51
# 2025-05-01 13:55:04,442 INFO: Processing shop: https://emalls.ir/Shop/374/
# 2025-05-01 13:55:06,313 INFO: Saved shop id=52
# 2025-05-01 13:55:07,314 INFO: Processing shop: https://emalls.ir/Shop/22242/
# 2025-05-01 13:55:08,699 INFO: Saved shop id=53
# 2025-05-01 13:55:09,700 INFO: Processing shop: https://emalls.ir/Shop/19637/
# 2025-05-01 13:55:10,857 INFO: Saved shop id=54
# 2025-05-01 13:55:11,858 INFO: Processing shop: https://emalls.ir/Shop/2091/
# 2025-05-01 13:55:15,215 INFO: Saved shop id=55
# 2025-05-01 13:55:16,217 INFO: Processing shop: https://emalls.ir/Shop/2604/
# 2025-05-01 13:55:17,370 INFO: Saved shop id=56
# 2025-05-01 13:55:18,371 INFO: Processing shop: https://emalls.ir/Shop/26022/
# 2025-05-01 13:55:19,745 INFO: Saved shop id=57
# 2025-05-01 13:55:20,747 INFO: Processing shop: https://emalls.ir/Shop/4664/
# 2025-05-01 13:55:22,056 INFO: Saved shop id=58
# 2025-05-01 13:55:23,057 INFO: Processing shop: https://emalls.ir/Shop/6559/
# 2025-05-01 13:55:25,782 INFO: Saved shop id=59
# 2025-05-01 13:55:26,783 INFO: Processing shop: https://emalls.ir/Shop/3648/
# 2025-05-01 13:55:28,833 INFO: Saved shop id=60
# 2025-05-01 13:55:29,834 INFO: Processing shop: https://emalls.ir/Shop/29799/
# 2025-05-01 13:55:31,329 INFO: Saved shop id=61
# 2025-05-01 13:55:32,331 INFO: Processing shop: https://emalls.ir/Shop/3169/
# 2025-05-01 13:55:33,394 INFO: Saved shop id=62
# 2025-05-01 13:55:34,396 INFO: Processing shop: https://emalls.ir/Shop/27561/
# 2025-05-01 13:55:36,210 INFO: Saved shop id=63
# 2025-05-01 13:55:37,212 INFO: Processing shop: https://emalls.ir/Shop/18455/
# 2025-05-01 13:55:38,014 INFO: Saved shop id=64
# 2025-05-01 13:55:39,016 INFO: Processing shop: https://emalls.ir/Shop/31657/
# 2025-05-01 13:55:40,392 INFO: Saved shop id=65
# 2025-05-01 13:55:41,393 INFO: Processing shop: https://emalls.ir/Shop/2706/
# 2025-05-01 13:55:42,769 INFO: Saved shop id=66
# 2025-05-01 13:55:43,770 INFO: Processing shop: https://emalls.ir/Shop/5282/
# 2025-05-01 13:55:45,490 INFO: Saved shop id=67
# 2025-05-01 13:55:46,491 INFO: Processing shop: https://emalls.ir/Shop/19346/
# 2025-05-01 13:55:49,055 INFO: Saved shop id=68
# 2025-05-01 13:55:50,056 INFO: Processing shop: https://emalls.ir/Shop/25055/
# 2025-05-01 13:55:52,039 INFO: Saved shop id=69
# 2025-05-01 13:55:53,040 INFO: Processing shop: https://emalls.ir/Shop/23978/
# 2025-05-01 13:55:55,606 INFO: Saved shop id=70
# 2025-05-01 13:55:56,607 INFO: Processing shop: https://emalls.ir/Shop/37960/
# 2025-05-01 13:55:59,174 INFO: Saved shop id=71
# 2025-05-01 13:56:00,176 INFO: Processing shop: https://emalls.ir/Shop/734/
# 2025-05-01 13:56:04,811 INFO: Saved shop id=72
# 2025-05-01 13:56:05,813 INFO: Processing shop: https://emalls.ir/Shop/1651/
# 2025-05-01 13:56:08,398 INFO: Saved shop id=73
# 2025-05-01 13:56:09,400 INFO: Processing shop: https://emalls.ir/Shop/4319/
# 2025-05-01 13:56:12,353 INFO: Saved shop id=74
# 2025-05-01 13:56:13,354 INFO: Processing shop: https://emalls.ir/Shop/2760/
# 2025-05-01 13:56:14,646 INFO: Saved shop id=75
# 2025-05-01 13:56:15,647 INFO: Processing shop: https://emalls.ir/Shop/612/
# 2025-05-01 13:56:16,613 INFO: Saved shop id=76
# 2025-05-01 13:56:17,615 INFO: Processing shop: https://emalls.ir/Shop/5223/
# 2025-05-01 13:56:19,006 INFO: Saved shop id=77
# 2025-05-01 13:56:20,007 INFO: Processing shop: https://emalls.ir/Shop/1854/
# 2025-05-01 13:56:22,570 INFO: Saved shop id=78
# 2025-05-01 13:56:23,571 INFO: Processing shop: https://emalls.ir/Shop/53506/
# 2025-05-01 13:56:24,789 INFO: Saved shop id=79
# 2025-05-01 13:56:25,791 INFO: Processing shop: https://emalls.ir/Shop/1117/
# 2025-05-01 13:56:27,237 INFO: Saved shop id=80
# 2025-05-01 13:56:28,239 INFO: Processing shop: https://emalls.ir/Shop/57888/
# 2025-05-01 13:56:28,918 INFO: Saved shop id=81
# 2025-05-01 13:56:29,919 INFO: Processing shop: https://emalls.ir/Shop/4545/
# 2025-05-01 13:56:31,031 INFO: Saved shop id=82
# 2025-05-01 13:56:32,033 INFO: Processing shop: https://emalls.ir/Shop/18862/
# 2025-05-01 13:56:32,973 INFO: Saved shop id=83
# 2025-05-01 13:56:33,974 INFO: Processing shop: https://emalls.ir/Shop/33971/
# 2025-05-01 13:56:35,099 INFO: Saved shop id=84
# 2025-05-01 13:56:36,101 INFO: Processing shop: https://emalls.ir/Shop/24861/
# 2025-05-01 13:56:37,671 INFO: Saved shop id=85
# 2025-05-01 13:56:38,672 INFO: Processing shop: https://emalls.ir/Shop/51542/
# 2025-05-01 13:56:40,044 INFO: Saved shop id=86
# 2025-05-01 13:56:41,045 INFO: Processing shop: https://emalls.ir/Shop/27473/
# 2025-05-01 13:56:41,633 INFO: Saved shop id=87
# 2025-05-01 13:56:42,635 INFO: Processing shop: https://emalls.ir/Shop/3229/
# 2025-05-01 13:56:44,353 INFO: Saved shop id=88
# 2025-05-01 13:56:45,354 INFO: Processing shop: https://emalls.ir/Shop/795/
# 2025-05-01 13:56:46,830 INFO: Saved shop id=89
# 2025-05-01 13:56:47,831 INFO: Processing shop: https://emalls.ir/Shop/28758/
# 2025-05-01 13:56:49,695 INFO: Saved shop id=90
# 2025-05-01 13:56:50,696 INFO: Processing shop: https://emalls.ir/Shop/1218/
# 2025-05-01 13:56:51,665 INFO: Saved shop id=91
# 2025-05-01 13:56:52,666 INFO: Processing shop: https://emalls.ir/Shop/34094/
# 2025-05-01 13:56:53,650 INFO: Saved shop id=92
# 2025-05-01 13:56:54,651 INFO: Processing shop: https://emalls.ir/Shop/40176/
# 2025-05-01 13:56:56,247 INFO: Saved shop id=93
# 2025-05-01 13:56:57,248 INFO: Processing shop: https://emalls.ir/Shop/2159/
# 2025-05-01 13:56:58,627 INFO: Saved shop id=94
# 2025-05-01 13:56:59,629 INFO: Processing shop: https://emalls.ir/Shop/1892/
# 2025-05-01 13:57:03,041 INFO: Saved shop id=95
# 2025-05-01 13:57:04,042 INFO: Processing shop: https://emalls.ir/Shop/30740/
# 2025-05-01 13:57:05,358 INFO: Saved shop id=96
# 2025-05-01 13:57:06,360 INFO: Processing shop: https://emalls.ir/Shop/24794/
# 2025-05-01 13:57:07,971 INFO: Saved shop id=97
# 2025-05-01 13:57:08,972 INFO: Processing shop: https://emalls.ir/Shop/32263/
# 2025-05-01 13:57:10,484 INFO: Saved shop id=98
# 2025-05-01 13:57:11,485 INFO: Processing shop: https://emalls.ir/Shop/25465/
# 2025-05-01 13:57:12,270 INFO: Saved shop id=99
# 2025-05-01 13:57:13,271 INFO: Processing shop: https://emalls.ir/Shop/20366/
# 2025-05-01 13:57:14,746 INFO: Saved shop id=100
# 2025-05-01 13:57:15,748 INFO: Processing shop: https://emalls.ir/Shop/32632/
# 2025-05-01 13:57:17,314 INFO: Saved shop id=101
# 2025-05-01 13:57:18,315 INFO: Processing shop: https://emalls.ir/Shop/21770/
# 2025-05-01 13:57:21,254 INFO: Saved shop id=102
# 2025-05-01 13:57:22,255 INFO: Processing shop: https://emalls.ir/Shop/22200/
# 2025-05-01 13:57:23,492 INFO: Saved shop id=103
# 2025-05-01 13:57:24,494 INFO: Processing shop: https://emalls.ir/Shop/5066/
# 2025-05-01 13:57:26,436 INFO: Saved shop id=104
# 2025-05-01 13:57:27,438 INFO: Processing shop: https://emalls.ir/Shop/27357/
# 2025-05-01 13:57:28,814 INFO: Saved shop id=105
# 2025-05-01 13:57:29,815 INFO: Processing shop: https://emalls.ir/Shop/799/
# 2025-05-01 13:57:33,153 INFO: Saved shop id=106
# 2025-05-01 13:57:34,154 INFO: Processing shop: https://emalls.ir/Shop/1573/
# 2025-05-01 13:57:37,290 INFO: Saved shop id=107
# 2025-05-01 13:57:38,291 INFO: Processing shop: https://emalls.ir/Shop/4638/
# 2025-05-01 13:57:40,632 INFO: Saved shop id=108
# 2025-05-01 13:57:41,633 INFO: Processing shop: https://emalls.ir/Shop/19896/
# 2025-05-01 13:57:44,703 INFO: Saved shop id=109
# 2025-05-01 13:57:45,705 INFO: Processing shop: https://emalls.ir/Shop/7704/
# 2025-05-01 13:57:47,390 INFO: Saved shop id=110
# 2025-05-01 13:57:48,391 INFO: Processing shop: https://emalls.ir/Shop/29877/
# 2025-05-01 13:57:51,487 INFO: Saved shop id=111
# 2025-05-01 13:57:52,488 INFO: Processing shop: https://emalls.ir/Shop/43656/
# 2025-05-01 13:57:53,784 INFO: Saved shop id=112
# 2025-05-01 13:57:54,786 INFO: Processing shop: https://emalls.ir/Shop/24216/
# 2025-05-01 13:57:56,673 INFO: Saved shop id=113
# 2025-05-01 13:57:57,674 INFO: Processing shop: https://emalls.ir/Shop/23453/
# 2025-05-01 13:57:59,560 INFO: Saved shop id=114
# 2025-05-01 13:58:00,561 INFO: Processing shop: https://emalls.ir/Shop/24497/
# 2025-05-01 13:58:02,544 INFO: Saved shop id=115
# 2025-05-01 13:58:03,545 INFO: Processing shop: https://emalls.ir/Shop/1713/
# 2025-05-01 13:58:06,279 INFO: Saved shop id=116
# 2025-05-01 13:58:07,281 INFO: Processing shop: https://emalls.ir/Shop/55552/
# 2025-05-01 13:58:08,699 INFO: Saved shop id=117
# 2025-05-01 13:58:09,701 INFO: Processing shop: https://emalls.ir/Shop/25027/
# 2025-05-01 13:58:11,379 INFO: Saved shop id=118
# 2025-05-01 13:58:12,380 INFO: Processing shop: https://emalls.ir/Shop/19279/
# 2025-05-01 13:58:13,755 INFO: Saved shop id=119
# 2025-05-01 13:58:14,756 INFO: Processing shop: https://emalls.ir/Shop/3656/
# 2025-05-01 13:58:18,312 INFO: Saved shop id=120
# 2025-05-01 13:58:19,313 INFO: Processing shop: https://emalls.ir/Shop/19987/
# 2025-05-01 13:58:20,704 INFO: Saved shop id=121
# 2025-05-01 13:58:21,705 INFO: Processing shop: https://emalls.ir/Shop/22820/
# 2025-05-01 13:58:22,486 INFO: Saved shop id=122
# 2025-05-01 13:58:23,487 INFO: Processing shop: https://emalls.ir/Shop/3567/
# 2025-05-01 13:58:26,231 INFO: Saved shop id=123
# 2025-05-01 13:58:27,232 INFO: Processing shop: https://emalls.ir/Shop/28730/
# 2025-05-01 13:58:29,312 INFO: Saved shop id=124
# 2025-05-01 13:58:30,313 INFO: Processing shop: https://emalls.ir/Shop/4805/
# 2025-05-01 13:58:34,866 INFO: Saved shop id=125
# 2025-05-01 13:58:35,868 INFO: Processing shop: https://emalls.ir/Shop/3736/
# 2025-05-01 13:58:38,012 INFO: Saved shop id=126
# 2025-05-01 13:58:39,013 INFO: Processing shop: https://emalls.ir/Shop/41688/
# 2025-05-01 13:58:41,451 INFO: Saved shop id=127
# 2025-05-01 13:58:42,452 INFO: Processing shop: https://emalls.ir/Shop/2771/
# 2025-05-01 13:58:44,997 INFO: Saved shop id=128
# 2025-05-01 13:58:45,999 INFO: Processing shop: https://emalls.ir/Shop/45870/
# 2025-05-01 13:58:48,014 INFO: Saved shop id=129
# 2025-05-01 13:58:49,015 INFO: Processing shop: https://emalls.ir/Shop/3879/
# 2025-05-01 13:58:52,407 INFO: Saved shop id=130
# 2025-05-01 13:58:53,409 INFO: Processing shop: https://emalls.ir/Shop/4505/
# 2025-05-01 13:58:56,204 INFO: Saved shop id=131
# 2025-05-01 13:58:57,205 INFO: Processing shop: https://emalls.ir/Shop/32985/
# 2025-05-01 13:58:59,649 INFO: Saved shop id=132
# 2025-05-01 13:59:00,651 INFO: Processing shop: https://emalls.ir/Shop/2852/
# 2025-05-01 13:59:04,104 INFO: Saved shop id=133
# 2025-05-01 13:59:05,105 INFO: Processing shop: https://emalls.ir/Shop/41250/
# 2025-05-01 13:59:07,149 INFO: Saved shop id=134
# 2025-05-01 13:59:08,150 INFO: Processing shop: https://emalls.ir/Shop/7831/
# 2025-05-01 13:59:13,774 INFO: Saved shop id=135
# 2025-05-01 13:59:14,775 INFO: Processing shop: https://emalls.ir/Shop/24255/
# 2025-05-01 13:59:16,975 INFO: Saved shop id=136
# 2025-05-01 13:59:17,976 INFO: Processing shop: https://emalls.ir/Shop/1036/
# 2025-05-01 13:59:21,680 INFO: Saved shop id=137
# 2025-05-01 13:59:22,681 INFO: Processing shop: https://emalls.ir/Shop/20558/
# 2025-05-01 13:59:24,187 INFO: Saved shop id=138
# 2025-05-01 13:59:25,189 INFO: Processing shop: https://emalls.ir/Shop/25036/
# 2025-05-01 13:59:27,743 INFO: Saved shop id=139
# 2025-05-01 13:59:28,744 INFO: Processing shop: https://emalls.ir/Shop/29189/
# 2025-05-01 13:59:30,632 INFO: Saved shop id=140
# 2025-05-01 13:59:31,633 INFO: Processing shop: https://emalls.ir/Shop/22166/
# 2025-05-01 13:59:33,119 INFO: Saved shop id=141
# 2025-05-01 13:59:34,120 INFO: Processing shop: https://emalls.ir/Shop/4731/
# 2025-05-01 13:59:36,168 INFO: Saved shop id=142
# 2025-05-01 13:59:37,169 INFO: Processing shop: https://emalls.ir/Shop/34823/
# 2025-05-01 13:59:38,862 INFO: Saved shop id=143
# 2025-05-01 13:59:39,863 INFO: Processing shop: https://emalls.ir/Shop/20899/
# 2025-05-01 13:59:41,079 INFO: Saved shop id=144
# 2025-05-01 13:59:42,080 INFO: Processing shop: https://emalls.ir/Shop/4615/
# 2025-05-01 13:59:42,797 INFO: Saved shop id=145
# 2025-05-01 13:59:43,799 INFO: Processing shop: https://emalls.ir/Shop/27254/
# 2025-05-01 13:59:44,498 INFO: Saved shop id=146
# 2025-05-01 13:59:45,499 INFO: Processing shop: https://emalls.ir/Shop/23692/
# 2025-05-01 13:59:47,464 INFO: Saved shop id=147
# 2025-05-01 13:59:48,465 INFO: Processing shop: https://emalls.ir/Shop/26688/
# 2025-05-01 13:59:49,459 INFO: Saved shop id=148
# 2025-05-01 13:59:50,461 INFO: Processing shop: https://emalls.ir/Shop/52451/
# 2025-05-01 13:59:51,655 INFO: Saved shop id=149
# 2025-05-01 13:59:52,656 INFO: Processing shop: https://emalls.ir/Shop/6046/
# 2025-05-01 13:59:55,506 INFO: Saved shop id=150
# 2025-05-01 13:59:56,508 INFO: Processing shop: https://emalls.ir/Shop/3098/
# 2025-05-01 13:59:58,894 INFO: Saved shop id=151
# 2025-05-01 13:59:59,896 INFO: Processing shop: https://emalls.ir/Shop/6329/
# 2025-05-01 14:00:01,637 INFO: Saved shop id=152
# 2025-05-01 14:00:02,638 INFO: Processing shop: https://emalls.ir/Shop/41127/
# 2025-05-01 14:00:04,297 INFO: Saved shop id=153
# 2025-05-01 14:00:05,299 INFO: Processing shop: https://emalls.ir/Shop/27047/
# 2025-05-01 14:00:06,910 INFO: Saved shop id=154
# 2025-05-01 14:00:07,911 INFO: Processing shop: https://emalls.ir/Shop/23837/
# 2025-05-01 14:00:09,991 INFO: Saved shop id=155
# 2025-05-01 14:00:10,992 INFO: Processing shop: https://emalls.ir/Shop/3121/
# 2025-05-01 14:00:12,064 INFO: Saved shop id=156
# 2025-05-01 14:00:13,065 INFO: Processing shop: https://emalls.ir/Shop/1867/
# 2025-05-01 14:00:16,565 INFO: Saved shop id=157
# 2025-05-01 14:00:17,566 INFO: Processing shop: https://emalls.ir/Shop/19791/
# 2025-05-01 14:00:19,349 INFO: Saved shop id=158
# 2025-05-01 14:00:20,351 INFO: Processing shop: https://emalls.ir/Shop/3960/
# 2025-05-01 14:00:23,146 INFO: Saved shop id=159
# 2025-05-01 14:00:24,148 INFO: Processing shop: https://emalls.ir/Shop/6897/
# 2025-05-01 14:00:26,466 INFO: Saved shop id=160
# 2025-05-01 14:00:27,468 INFO: Processing shop: https://emalls.ir/Shop/6094/
# 2025-05-01 14:00:29,447 INFO: Saved shop id=161
# 2025-05-01 14:00:30,449 INFO: Processing shop: https://emalls.ir/Shop/31535/
# 2025-05-01 14:00:33,536 INFO: Saved shop id=162
# 2025-05-01 14:00:34,537 INFO: Processing shop: https://emalls.ir/Shop/28797/
# 2025-05-01 14:00:38,166 INFO: Saved shop id=163
# 2025-05-01 14:00:39,167 INFO: Processing shop: https://emalls.ir/Shop/26169/
# 2025-05-01 14:00:40,479 INFO: Saved shop id=164
# 2025-05-01 14:00:41,480 INFO: Processing shop: https://emalls.ir/Shop/23310/
# 2025-05-01 14:00:43,135 INFO: Saved shop id=165
# 2025-05-01 14:00:44,137 INFO: Processing shop: https://emalls.ir/Shop/4296/
# 2025-05-01 14:00:45,363 INFO: Saved shop id=166
# 2025-05-01 14:00:46,365 INFO: Processing shop: https://emalls.ir/Shop/36264/
# 2025-05-01 14:00:47,787 INFO: Saved shop id=167
# 2025-05-01 14:00:48,788 INFO: Processing shop: https://emalls.ir/Shop/26824/
# 2025-05-01 14:00:49,925 INFO: Saved shop id=168
# 2025-05-01 14:00:50,926 INFO: Processing shop: https://emalls.ir/Shop/1721/
# 2025-05-01 14:00:52,650 INFO: Saved shop id=169
# 2025-05-01 14:00:53,651 INFO: Processing shop: https://emalls.ir/Shop/2316/
# 2025-05-01 14:00:55,642 INFO: Saved shop id=170
# 2025-05-01 14:00:56,643 INFO: Processing shop: https://emalls.ir/Shop/1885/
# 2025-05-01 14:01:00,528 INFO: Saved shop id=171
# 2025-05-01 14:01:01,529 INFO: Processing shop: https://emalls.ir/Shop/39405/
# 2025-05-01 14:01:04,014 INFO: Saved shop id=172
# 2025-05-01 14:01:05,015 INFO: Processing shop: https://emalls.ir/Shop/19835/
# 2025-05-01 14:01:08,471 INFO: Saved shop id=173
# 2025-05-01 14:01:09,472 INFO: Processing shop: https://emalls.ir/Shop/43771/
# 2025-05-01 14:01:11,231 INFO: Saved shop id=174
# 2025-05-01 14:01:12,232 INFO: Processing shop: https://emalls.ir/Shop/50171/
# 2025-05-01 14:01:13,842 INFO: Saved shop id=175
# 2025-05-01 14:01:14,844 INFO: Processing shop: https://emalls.ir/Shop/3861/
# 2025-05-01 14:01:15,572 INFO: Saved shop id=176
# 2025-05-01 14:01:16,573 INFO: Processing shop: https://emalls.ir/Shop/23244/
# 2025-05-01 14:01:20,026 INFO: Saved shop id=177
# 2025-05-01 14:01:21,121 INFO: Processing shop: https://emalls.ir/Shop/4549/
# 2025-05-01 14:01:23,334 INFO: Saved shop id=178
# 2025-05-01 14:01:24,335 INFO: Processing shop: https://emalls.ir/Shop/20449/
# 2025-05-01 14:01:26,738 INFO: Saved shop id=179
# 2025-05-01 14:01:27,739 INFO: Processing shop: https://emalls.ir/Shop/2075/
# 2025-05-01 14:01:30,503 INFO: Saved shop id=180
# 2025-05-01 14:01:31,504 INFO: Processing shop: https://emalls.ir/Shop/3443/
# 2025-05-01 14:01:34,280 INFO: Saved shop id=181
# 2025-05-01 14:01:35,281 INFO: Processing shop: https://emalls.ir/Shop/3696/
# 2025-05-01 14:01:37,438 INFO: Saved shop id=182
# 2025-05-01 14:01:38,439 INFO: Processing shop: https://emalls.ir/Shop/5312/
# 2025-05-01 14:01:42,334 INFO: Saved shop id=183
# 2025-05-01 14:01:43,335 INFO: Processing shop: https://emalls.ir/Shop/31864/
# 2025-05-01 14:01:44,411 INFO: Saved shop id=184
# 2025-05-01 14:01:45,413 INFO: Processing shop: https://emalls.ir/Shop/43452/
# 2025-05-01 14:01:48,305 INFO: Saved shop id=185
# 2025-05-01 14:01:49,307 INFO: Processing shop: https://emalls.ir/Shop/22167/
# 2025-05-01 14:01:50,790 INFO: Saved shop id=186
# 2025-05-01 14:01:51,792 INFO: Processing shop: https://emalls.ir/Shop/36064/
# 2025-05-01 14:01:53,551 INFO: Saved shop id=187
# 2025-05-01 14:01:54,552 INFO: Processing shop: https://emalls.ir/Shop/34436/
# 2025-05-01 14:01:56,056 INFO: Saved shop id=188
# 2025-05-01 14:01:57,057 INFO: Processing shop: https://emalls.ir/Shop/30678/
# 2025-05-01 14:01:57,497 INFO: Saved shop id=189
# 2025-05-01 14:01:58,498 INFO: Processing shop: https://emalls.ir/Shop/25126/
# 2025-05-01 14:01:59,779 INFO: Saved shop id=190
# 2025-05-01 14:02:00,781 INFO: Processing shop: https://emalls.ir/Shop/1943/
# 2025-05-01 14:02:02,621 INFO: Saved shop id=191
# 2025-05-01 14:02:03,622 INFO: Processing shop: https://emalls.ir/Shop/36350/
# 2025-05-01 14:02:06,435 INFO: Saved shop id=192
# 2025-05-01 14:02:07,436 INFO: Processing shop: https://emalls.ir/Shop/969/
# 2025-05-01 14:02:09,382 INFO: Saved shop id=193
# 2025-05-01 14:02:10,383 INFO: Processing shop: https://emalls.ir/Shop/2209/
# 2025-05-01 14:02:13,274 INFO: Saved shop id=194
# 2025-05-01 14:02:14,275 INFO: Processing shop: https://emalls.ir/Shop/2847/
# 2025-05-01 14:02:14,917 INFO: Saved shop id=195
# 2025-05-01 14:02:15,918 INFO: Processing shop: https://emalls.ir/Shop/22402/
# 2025-05-01 14:02:17,757 INFO: Saved shop id=196
# 2025-05-01 14:02:18,758 INFO: Processing shop: https://emalls.ir/Shop/3220/
# 2025-05-01 14:02:22,855 INFO: Saved shop id=197
# 2025-05-01 14:02:23,857 INFO: Processing shop: https://emalls.ir/Shop/33310/
# 2025-05-01 14:02:24,920 INFO: Saved shop id=198
# 2025-05-01 14:02:25,921 INFO: Processing shop: https://emalls.ir/Shop/1012/
# 2025-05-01 14:02:26,669 INFO: Saved shop id=199
# 2025-05-01 14:02:27,670 INFO: Processing shop: https://emalls.ir/Shop/33053/
# 2025-05-01 14:02:28,749 INFO: Saved shop id=200
# 2025-05-01 14:02:29,750 INFO: Processing shop: https://emalls.ir/Shop/54631/
# 2025-05-01 14:02:31,908 INFO: Saved shop id=201
# 2025-05-01 14:02:32,909 INFO: Processing shop: https://emalls.ir/Shop/41317/
# 2025-05-01 14:02:36,643 INFO: Saved shop id=202
# 2025-05-01 14:02:37,644 INFO: Processing shop: https://emalls.ir/Shop/7470/
# 2025-05-01 14:02:39,794 INFO: Saved shop id=203
# 2025-05-01 14:02:40,796 INFO: Processing shop: https://emalls.ir/Shop/1143/
# 2025-05-01 14:02:42,634 INFO: Saved shop id=204
# 2025-05-01 14:02:43,635 INFO: Processing shop: https://emalls.ir/Shop/7775/
# 2025-05-01 14:02:47,110 INFO: Saved shop id=205
# 2025-05-01 14:02:48,111 INFO: Processing shop: https://emalls.ir/Shop/7253/
# 2025-05-01 14:02:49,575 INFO: Saved shop id=206
# 2025-05-01 14:02:50,576 INFO: Processing shop: https://emalls.ir/Shop/4440/
# 2025-05-01 14:02:52,641 INFO: Saved shop id=207
# 2025-05-01 14:02:53,642 INFO: Processing shop: https://emalls.ir/Shop/7352/
# 2025-05-01 14:02:55,155 INFO: Saved shop id=208
# 2025-05-01 14:02:56,157 INFO: Processing shop: https://emalls.ir/Shop/3171/
# 2025-05-01 14:02:57,946 INFO: Saved shop id=209
# 2025-05-01 14:02:58,947 INFO: Processing shop: https://emalls.ir/Shop/904/
# 2025-05-01 14:03:00,654 INFO: Saved shop id=210
# 2025-05-01 14:03:01,655 INFO: Processing shop: https://emalls.ir/Shop/24473/
# 2025-05-01 14:03:02,162 INFO: Saved shop id=211
# 2025-05-01 14:03:03,163 INFO: Processing shop: https://emalls.ir/Shop/24195/
# 2025-05-01 14:03:05,238 INFO: Saved shop id=212
# 2025-05-01 14:03:06,239 INFO: Processing shop: https://emalls.ir/Shop/18073/
# 2025-05-01 14:03:08,602 INFO: Saved shop id=213
# 2025-05-01 14:03:09,603 INFO: Processing shop: https://emalls.ir/Shop/1924/
# 2025-05-01 14:03:11,445 INFO: Saved shop id=214
# 2025-05-01 14:03:12,446 INFO: Processing shop: https://emalls.ir/Shop/2078/
# 2025-05-01 14:03:15,257 INFO: Saved shop id=215
# 2025-05-01 14:03:16,258 INFO: Processing shop: https://emalls.ir/Shop/676/
# 2025-05-01 14:03:19,158 INFO: Saved shop id=216
# 2025-05-01 14:03:20,159 INFO: Processing shop: https://emalls.ir/Shop/23323/
# 2025-05-01 14:03:22,819 INFO: Saved shop id=217
# 2025-05-01 14:03:23,820 INFO: Processing shop: https://emalls.ir/Shop/5120/
# 2025-05-01 14:03:24,971 INFO: Saved shop id=218
# 2025-05-01 14:03:25,973 INFO: Processing shop: https://emalls.ir/Shop/5778/
# 2025-05-01 14:03:28,152 INFO: Saved shop id=219
# 2025-05-01 14:03:29,153 INFO: Processing shop: https://emalls.ir/Shop/36863/
# 2025-05-01 14:03:30,887 INFO: Saved shop id=220
# 2025-05-01 14:03:31,888 INFO: Processing shop: https://emalls.ir/Shop/4982/
# 2025-05-01 14:03:34,558 INFO: Saved shop id=221
# 2025-05-01 14:03:35,559 INFO: Processing shop: https://emalls.ir/Shop/5659/
# 2025-05-01 14:03:37,502 INFO: Saved shop id=222
# 2025-05-01 14:03:38,503 INFO: Processing shop: https://emalls.ir/Shop/41906/
# 2025-05-01 14:03:39,127 INFO: Saved shop id=223
# 2025-05-01 14:03:40,128 INFO: Processing shop: https://emalls.ir/Shop/7317/
# 2025-05-01 14:03:41,355 INFO: Saved shop id=224
# 2025-05-01 14:03:42,356 INFO: Processing shop: https://emalls.ir/Shop/30333/
# 2025-05-01 14:03:45,261 INFO: Saved shop id=225
# 2025-05-01 14:03:46,263 INFO: Processing shop: https://emalls.ir/Shop/3499/
# 2025-05-01 14:03:48,105 INFO: Saved shop id=226
# 2025-05-01 14:03:49,106 INFO: Processing shop: https://emalls.ir/Shop/28773/
# 2025-05-01 14:03:50,542 INFO: Saved shop id=227
# 2025-05-01 14:03:51,544 INFO: Processing shop: https://emalls.ir/Shop/2073/
# 2025-05-01 14:03:53,366 INFO: Saved shop id=228
# 2025-05-01 14:03:54,367 INFO: Processing shop: https://emalls.ir/Shop/42622/
# 2025-05-01 14:03:55,933 INFO: Saved shop id=229
# 2025-05-01 14:03:56,934 INFO: Processing shop: https://emalls.ir/Shop/2473/
# 2025-05-01 14:03:58,559 INFO: Saved shop id=230
# 2025-05-01 14:03:59,560 INFO: Processing shop: https://emalls.ir/Shop/4551/
# 2025-05-01 14:04:01,501 INFO: Saved shop id=231
# 2025-05-01 14:04:02,502 INFO: Processing shop: https://emalls.ir/Shop/20578/
# 2025-05-01 14:04:03,157 INFO: Saved shop id=232
# 2025-05-01 14:04:04,158 INFO: Processing shop: https://emalls.ir/Shop/464/
# 2025-05-01 14:04:05,706 INFO: Saved shop id=233
# 2025-05-01 14:04:06,707 INFO: Processing shop: https://emalls.ir/Shop/38941/
# 2025-05-01 14:04:07,368 INFO: Saved shop id=234
# 2025-05-01 14:04:08,370 INFO: Processing shop: https://emalls.ir/Shop/52212/
# 2025-05-01 14:04:10,563 INFO: Saved shop id=235
# 2025-05-01 14:04:11,565 INFO: Processing shop: https://emalls.ir/Shop/23575/
# 2025-05-01 14:04:13,850 INFO: Saved shop id=236
# 2025-05-01 14:04:14,851 INFO: Processing shop: https://emalls.ir/Shop/18848/
# 2025-05-01 14:04:16,835 INFO: Saved shop id=237
# 2025-05-01 14:04:17,836 INFO: Processing shop: https://emalls.ir/Shop/35504/
# 2025-05-01 14:04:19,451 INFO: Saved shop id=238
# 2025-05-01 14:04:20,452 INFO: Processing shop: https://emalls.ir/Shop/48024/
# 2025-05-01 14:04:23,279 INFO: Saved shop id=239
# 2025-05-01 14:04:24,280 INFO: Processing shop: https://emalls.ir/Shop/31583/
# 2025-05-01 14:04:26,078 INFO: Saved shop id=240
# 2025-05-01 14:04:27,079 INFO: Processing shop: https://emalls.ir/Shop/18145/
# 2025-05-01 14:04:29,082 INFO: Saved shop id=241
# 2025-05-01 14:04:30,084 INFO: Processing shop: https://emalls.ir/Shop/30799/
# 2025-05-01 14:04:32,851 INFO: Saved shop id=242
# 2025-05-01 14:04:33,852 INFO: Processing shop: https://emalls.ir/Shop/745/
# 2025-05-01 14:04:34,569 INFO: Saved shop id=243
# 2025-05-01 14:04:35,571 INFO: Processing shop: https://emalls.ir/Shop/5106/
# 2025-05-01 14:04:36,581 INFO: Saved shop id=244
# 2025-05-01 14:04:37,583 INFO: Processing shop: https://emalls.ir/Shop/19352/
# 2025-05-01 14:04:39,431 INFO: Saved shop id=245
# 2025-05-01 14:04:40,433 INFO: Processing shop: https://emalls.ir/Shop/591/
# 2025-05-01 14:04:43,650 INFO: Saved shop id=246
# 2025-05-01 14:04:44,651 INFO: Processing shop: https://emalls.ir/Shop/55685/
# 2025-05-01 14:04:46,593 INFO: Saved shop id=247
# 2025-05-01 14:04:47,595 INFO: Processing shop: https://emalls.ir/Shop/7613/
# 2025-05-01 14:04:49,073 INFO: Saved shop id=248
# 2025-05-01 14:04:50,074 INFO: Processing shop: https://emalls.ir/Shop/741/
# 2025-05-01 14:04:53,652 INFO: Saved shop id=249
# 2025-05-01 14:04:54,653 INFO: Processing shop: https://emalls.ir/Shop/6985/
# 2025-05-01 14:04:56,955 INFO: Saved shop id=250
# 2025-05-01 14:04:57,956 INFO: Processing shop: https://emalls.ir/Shop/23563/
# 2025-05-01 14:05:01,658 INFO: Saved shop id=251
# 2025-05-01 14:05:02,659 INFO: Processing shop: https://emalls.ir/Shop/38207/
# 2025-05-01 14:05:04,590 INFO: Saved shop id=252
# 2025-05-01 14:05:05,592 INFO: Processing shop: https://emalls.ir/Shop/7133/
# 2025-05-01 14:05:06,531 INFO: Saved shop id=253
# 2025-05-01 14:05:07,532 INFO: Processing shop: https://emalls.ir/Shop/18415/
# 2025-05-01 14:05:08,998 INFO: Saved shop id=254
# 2025-05-01 14:05:09,999 INFO: Processing shop: https://emalls.ir/Shop/4478/
# 2025-05-01 14:05:11,381 INFO: Saved shop id=255
# 2025-05-01 14:05:12,382 INFO: Processing shop: https://emalls.ir/Shop/2090/
# 2025-05-01 14:05:13,626 INFO: Saved shop id=256
# 2025-05-01 14:05:14,627 INFO: Processing shop: https://emalls.ir/Shop/4372/
# 2025-05-01 14:05:15,536 INFO: Saved shop id=257
# 2025-05-01 14:05:16,537 INFO: Processing shop: https://emalls.ir/Shop/35257/
# 2025-05-01 14:05:17,245 INFO: Saved shop id=258
# 2025-05-01 14:05:18,246 INFO: Processing shop: https://emalls.ir/Shop/26750/
# 2025-05-01 14:05:19,493 INFO: Saved shop id=259
# 2025-05-01 14:05:20,494 INFO: Processing shop: https://emalls.ir/Shop/4330/
# 2025-05-01 14:05:22,456 INFO: Saved shop id=260
# 2025-05-01 14:05:23,457 INFO: Processing shop: https://emalls.ir/Shop/18441/
# 2025-05-01 14:05:24,884 INFO: Saved shop id=261
# 2025-05-01 14:05:25,886 INFO: Processing shop: https://emalls.ir/Shop/46508/
# 2025-05-01 14:05:28,275 INFO: Saved shop id=262
# 2025-05-01 14:05:29,277 INFO: Processing shop: https://emalls.ir/Shop/56870/
# 2025-05-01 14:05:31,093 INFO: Saved shop id=263
# 2025-05-01 14:05:32,094 INFO: Processing shop: https://emalls.ir/Shop/20021/
# 2025-05-01 14:05:35,629 INFO: Saved shop id=264
# 2025-05-01 14:05:36,630 INFO: Processing shop: https://emalls.ir/Shop/1650/
# 2025-05-01 14:05:39,625 INFO: Saved shop id=265
# 2025-05-01 14:05:40,627 INFO: Processing shop: https://emalls.ir/Shop/3643/
# 2025-05-01 14:05:42,802 INFO: Saved shop id=266
# 2025-05-01 14:05:43,803 INFO: Processing shop: https://emalls.ir/Shop/4277/
# 2025-05-01 14:05:46,385 INFO: Saved shop id=267
# 2025-05-01 14:05:47,386 INFO: Processing shop: https://emalls.ir/Shop/46592/
# 2025-05-01 14:05:49,280 INFO: Saved shop id=268
# 2025-05-01 14:05:50,281 INFO: Processing shop: https://emalls.ir/Shop/45584/
# 2025-05-01 14:05:52,284 INFO: Saved shop id=269
# 2025-05-01 14:05:53,286 INFO: Processing shop: https://emalls.ir/Shop/6122/
# 2025-05-01 14:05:56,109 INFO: Saved shop id=270
# 2025-05-01 14:05:57,110 INFO: Processing shop: https://emalls.ir/Shop/19258/
# 2025-05-01 14:05:59,608 INFO: Saved shop id=271
# 2025-05-01 14:06:00,610 INFO: Processing shop: https://emalls.ir/Shop/2061/
# 2025-05-01 14:06:02,541 INFO: Saved shop id=272
# 2025-05-01 14:06:03,542 INFO: Processing shop: https://emalls.ir/Shop/7850/
# 2025-05-01 14:06:04,665 INFO: Saved shop id=273
# 2025-05-01 14:06:05,667 INFO: Processing shop: https://emalls.ir/Shop/5886/
# 2025-05-01 14:06:08,111 INFO: Saved shop id=274
# 2025-05-01 14:06:09,112 INFO: Processing shop: https://emalls.ir/Shop/28254/
# 2025-05-01 14:06:12,101 INFO: Saved shop id=275
# 2025-05-01 14:06:13,103 INFO: Processing shop: https://emalls.ir/Shop/22717/
# 2025-05-01 14:06:15,241 INFO: Saved shop id=276
# 2025-05-01 14:06:16,242 INFO: Processing shop: https://emalls.ir/Shop/2674/
# 2025-05-01 14:06:17,499 INFO: Saved shop id=277
# 2025-05-01 14:06:18,500 INFO: Processing shop: https://emalls.ir/Shop/4844/
# 2025-05-01 14:06:21,860 INFO: Saved shop id=278
# 2025-05-01 14:06:22,861 INFO: Processing shop: https://emalls.ir/Shop/4821/
# 2025-05-01 14:06:24,376 INFO: Saved shop id=279
# 2025-05-01 14:06:25,377 INFO: Processing shop: https://emalls.ir/Shop/30102/
# 2025-05-01 14:06:27,581 INFO: Saved shop id=280
# 2025-05-01 14:06:28,583 INFO: Processing shop: https://emalls.ir/Shop/46328/
# 2025-05-01 14:06:32,060 INFO: Saved shop id=281
# 2025-05-01 14:06:33,061 INFO: Processing shop: https://emalls.ir/Shop/4009/
# 2025-05-01 14:06:34,647 INFO: Saved shop id=282
# 2025-05-01 14:06:35,648 INFO: Processing shop: https://emalls.ir/Shop/1987/
# 2025-05-01 14:06:36,816 INFO: Saved shop id=283
# 2025-05-01 14:06:37,817 INFO: Processing shop: https://emalls.ir/Shop/36002/
# 2025-05-01 14:06:39,266 INFO: Saved shop id=284
# 2025-05-01 14:06:40,268 INFO: Processing shop: https://emalls.ir/Shop/27872/
# 2025-05-01 14:06:42,590 INFO: Saved shop id=285
# 2025-05-01 14:06:43,591 INFO: Processing shop: https://emalls.ir/Shop/4686/
# 2025-05-01 14:06:45,745 INFO: Saved shop id=286
# 2025-05-01 14:06:46,746 INFO: Processing shop: https://emalls.ir/Shop/3872/
# 2025-05-01 14:06:48,180 INFO: Saved shop id=287
# 2025-05-01 14:06:49,182 INFO: Processing shop: https://emalls.ir/Shop/3454/
# 2025-05-01 14:06:51,440 INFO: Saved shop id=288
# 2025-05-01 14:06:52,442 INFO: Processing shop: https://emalls.ir/Shop/37118/
# 2025-05-01 14:06:53,120 INFO: Saved shop id=289
# 2025-05-01 14:06:54,121 INFO: Processing shop: https://emalls.ir/Shop/23604/
# 2025-05-01 14:06:55,383 INFO: Saved shop id=290
# 2025-05-01 14:06:56,384 INFO: Processing shop: https://emalls.ir/Shop/18861/
# 2025-05-01 14:06:58,453 INFO: Saved shop id=291
# 2025-05-01 14:06:59,454 INFO: Processing shop: https://emalls.ir/Shop/25518/
# 2025-05-01 14:07:00,266 INFO: Saved shop id=292
# 2025-05-01 14:07:01,267 INFO: Processing shop: https://emalls.ir/Shop/51094/
# 2025-05-01 14:07:02,781 INFO: Saved shop id=293
# 2025-05-01 14:07:03,783 INFO: Processing shop: https://emalls.ir/Shop/3074/
# 2025-05-01 14:07:05,518 INFO: Saved shop id=294
# 2025-05-01 14:07:06,519 INFO: Processing shop: https://emalls.ir/Shop/5263/
# 2025-05-01 14:07:07,313 INFO: Saved shop id=295
# 2025-05-01 14:07:08,314 INFO: Processing shop: https://emalls.ir/Shop/32842/
# 2025-05-01 14:07:09,324 INFO: Saved shop id=296
# 2025-05-01 14:07:10,325 INFO: Processing shop: https://emalls.ir/Shop/3782/
# 2025-05-01 14:07:13,220 INFO: Saved shop id=297
# 2025-05-01 14:07:14,221 INFO: Processing shop: https://emalls.ir/Shop/18087/
# 2025-05-01 14:07:16,196 INFO: Saved shop id=298
# 2025-05-01 14:07:17,197 INFO: Processing shop: https://emalls.ir/Shop/28545/
# 2025-05-01 14:07:19,260 INFO: Saved shop id=299
# 2025-05-01 14:07:20,261 INFO: Processing shop: https://emalls.ir/Shop/29879/
# 2025-05-01 14:07:22,201 INFO: Saved shop id=300
# 2025-05-01 14:07:23,202 INFO: Processing shop: https://emalls.ir/Shop/1707/
# 2025-05-01 14:07:25,033 INFO: Saved shop id=301
# 2025-05-01 14:07:26,034 INFO: Processing shop: https://emalls.ir/Shop/23669/
# 2025-05-01 14:07:28,877 INFO: Saved shop id=302
# 2025-05-01 14:07:29,878 INFO: Processing shop: https://emalls.ir/Shop/845/
# 2025-05-01 14:07:30,632 INFO: Saved shop id=303
# 2025-05-01 14:07:31,633 INFO: Processing shop: https://emalls.ir/Shop/5372/
# 2025-05-01 14:07:33,514 INFO: Saved shop id=304
# 2025-05-01 14:07:34,515 INFO: Processing shop: https://emalls.ir/Shop/44121/
# 2025-05-01 14:07:35,594 INFO: Saved shop id=305
# 2025-05-01 14:07:36,596 INFO: Processing shop: https://emalls.ir/Shop/23803/
# 2025-05-01 14:07:37,813 INFO: Saved shop id=306
# 2025-05-01 14:07:38,814 INFO: Processing shop: https://emalls.ir/Shop/2975/
# 2025-05-01 14:07:41,269 INFO: Saved shop id=307
# 2025-05-01 14:07:42,271 INFO: Processing shop: https://emalls.ir/Shop/5525/
# 2025-05-01 14:07:43,698 INFO: Saved shop id=308
# 2025-05-01 14:07:44,699 INFO: Processing shop: https://emalls.ir/Shop/19629/
# 2025-05-01 14:07:46,690 INFO: Saved shop id=309
# 2025-05-01 14:07:47,691 INFO: Processing shop: https://emalls.ir/Shop/32721/
# 2025-05-01 14:07:49,213 INFO: Saved shop id=310
# 2025-05-01 14:07:50,214 INFO: Processing shop: https://emalls.ir/Shop/38430/
# 2025-05-01 14:07:51,550 INFO: Saved shop id=311
# 2025-05-01 14:07:52,551 INFO: Processing shop: https://emalls.ir/Shop/2599/
# 2025-05-01 14:07:54,797 INFO: Saved shop id=312
# 2025-05-01 14:07:55,798 INFO: Processing shop: https://emalls.ir/Shop/1152/
# 2025-05-01 14:07:58,468 INFO: Saved shop id=313
# 2025-05-01 14:07:59,469 INFO: Processing shop: https://emalls.ir/Shop/1610/
# 2025-05-01 14:08:01,667 INFO: Saved shop id=314
# 2025-05-01 14:08:02,667 INFO: Processing shop: https://emalls.ir/Shop/30241/
# 2025-05-01 14:08:05,517 INFO: Saved shop id=315
# 2025-05-01 14:08:06,519 INFO: Processing shop: https://emalls.ir/Shop/23657/
# 2025-05-01 14:08:09,031 INFO: Saved shop id=316
# 2025-05-01 14:08:10,032 INFO: Processing shop: https://emalls.ir/Shop/3659/
# 2025-05-01 14:08:10,861 INFO: Saved shop id=317
# 2025-05-01 14:08:11,862 INFO: Processing shop: https://emalls.ir/Shop/31768/
# 2025-05-01 14:08:12,703 INFO: Saved shop id=318
# 2025-05-01 14:08:13,704 INFO: Processing shop: https://emalls.ir/Shop/21553/
# 2025-05-01 14:08:15,198 INFO: Saved shop id=319
# 2025-05-01 14:08:16,200 INFO: Processing shop: https://emalls.ir/Shop/19777/
# 2025-05-01 14:08:18,170 INFO: Saved shop id=320
# 2025-05-01 14:08:19,172 INFO: Processing shop: https://emalls.ir/Shop/22329/
# 2025-05-01 14:08:21,333 INFO: Saved shop id=321
# 2025-05-01 14:08:22,334 INFO: Processing shop: https://emalls.ir/Shop/28967/
# 2025-05-01 14:08:23,640 INFO: Saved shop id=322
# 2025-05-01 14:08:24,641 INFO: Processing shop: https://emalls.ir/Shop/3979/
# 2025-05-01 14:08:28,280 INFO: Saved shop id=323
# 2025-05-01 14:08:29,281 INFO: Processing shop: https://emalls.ir/Shop/18548/
# 2025-05-01 14:08:32,889 INFO: Saved shop id=324
# 2025-05-01 14:08:33,890 INFO: Processing shop: https://emalls.ir/Shop/2709/
# 2025-05-01 14:08:38,710 INFO: Saved shop id=325
# 2025-05-01 14:08:39,711 INFO: Processing shop: https://emalls.ir/Shop/5375/
# 2025-05-01 14:08:42,318 INFO: Saved shop id=326
# 2025-05-01 14:08:43,319 INFO: Processing shop: https://emalls.ir/Shop/2030/
# 2025-05-01 14:08:44,882 INFO: Saved shop id=327
# 2025-05-01 14:08:45,883 INFO: Processing shop: https://emalls.ir/Shop/19175/
# 2025-05-01 14:08:47,234 INFO: Saved shop id=328
# 2025-05-01 14:08:48,236 INFO: Processing shop: https://emalls.ir/Shop/34520/
# 2025-05-01 14:08:48,799 INFO: Saved shop id=329
# 2025-05-01 14:08:49,800 INFO: Processing shop: https://emalls.ir/Shop/18313/
# 2025-05-01 14:08:52,573 INFO: Saved shop id=330
# 2025-05-01 14:08:53,574 INFO: Processing shop: https://emalls.ir/Shop/18634/
# 2025-05-01 14:08:55,833 INFO: Saved shop id=331
# 2025-05-01 14:08:56,835 INFO: Processing shop: https://emalls.ir/Shop/5386/
# 2025-05-01 14:08:59,127 INFO: Saved shop id=332
# 2025-05-01 14:09:00,128 INFO: Processing shop: https://emalls.ir/Shop/5193/
# 2025-05-01 14:09:00,648 INFO: Saved shop id=333
# 2025-05-01 14:09:01,649 INFO: Processing shop: https://emalls.ir/Shop/23243/
# 2025-05-01 14:09:03,916 INFO: Saved shop id=334
# 2025-05-01 14:09:04,917 INFO: Processing shop: https://emalls.ir/Shop/18673/
# 2025-05-01 14:09:06,761 INFO: Saved shop id=335
# 2025-05-01 14:09:07,763 INFO: Processing shop: https://emalls.ir/Shop/43941/
# 2025-05-01 14:09:09,242 INFO: Saved shop id=336
# 2025-05-01 14:09:10,242 INFO: Processing shop: https://emalls.ir/Shop/25758/
# 2025-05-01 14:09:12,436 INFO: Saved shop id=337
# 2025-05-01 14:09:13,437 INFO: Processing shop: https://emalls.ir/Shop/18224/
# 2025-05-01 14:09:15,320 INFO: Saved shop id=338
# 2025-05-01 14:09:16,321 INFO: Processing shop: https://emalls.ir/Shop/5348/
# 2025-05-01 14:09:17,450 INFO: Saved shop id=339
# 2025-05-01 14:09:18,451 INFO: Processing shop: https://emalls.ir/Shop/4225/
# 2025-05-01 14:09:20,287 INFO: Saved shop id=340
# 2025-05-01 14:09:21,288 INFO: Processing shop: https://emalls.ir/Shop/17977/
# 2025-05-01 14:09:23,595 INFO: Saved shop id=341
# 2025-05-01 14:09:24,597 INFO: Processing shop: https://emalls.ir/Shop/1605/
# 2025-05-01 14:09:26,818 INFO: Saved shop id=342
# 2025-05-01 14:09:27,820 INFO: Processing shop: https://emalls.ir/Shop/30572/
# 2025-05-01 14:09:30,131 INFO: Saved shop id=343
# 2025-05-01 14:09:31,234 INFO: Processing shop: https://emalls.ir/Shop/44865/
# 2025-05-01 14:09:31,976 INFO: Saved shop id=344
# 2025-05-01 14:09:32,977 INFO: Processing shop: https://emalls.ir/Shop/2482/
# 2025-05-01 14:09:34,193 INFO: Saved shop id=345
# 2025-05-01 14:09:35,194 INFO: Processing shop: https://emalls.ir/Shop/47450/
# 2025-05-01 14:09:36,710 INFO: Saved shop id=346
# 2025-05-01 14:09:37,712 INFO: Processing shop: https://emalls.ir/Shop/766/
# 2025-05-01 14:09:38,645 INFO: Saved shop id=347
# 2025-05-01 14:09:39,646 INFO: Processing shop: https://emalls.ir/Shop/4501/
# 2025-05-01 14:09:41,640 INFO: Saved shop id=348
# 2025-05-01 14:09:42,641 INFO: Processing shop: https://emalls.ir/Shop/22685/
# 2025-05-01 14:09:44,090 INFO: Saved shop id=349
# 2025-05-01 14:09:45,091 INFO: Processing shop: https://emalls.ir/Shop/18854/
# 2025-05-01 14:09:48,578 INFO: Saved shop id=350
# 2025-05-01 14:09:49,579 INFO: Processing shop: https://emalls.ir/Shop/3939/
# 2025-05-01 14:09:50,368 INFO: Saved shop id=351
# 2025-05-01 14:09:51,370 INFO: Processing shop: https://emalls.ir/Shop/18125/
# 2025-05-01 14:09:53,215 INFO: Saved shop id=352
# 2025-05-01 14:09:54,216 INFO: Processing shop: https://emalls.ir/Shop/28494/
# 2025-05-01 14:09:55,447 INFO: Saved shop id=353
# 2025-05-01 14:09:56,449 INFO: Processing shop: https://emalls.ir/Shop/468/
# 2025-05-01 14:09:57,016 INFO: Saved shop id=354
# 2025-05-01 14:09:58,018 INFO: Processing shop: https://emalls.ir/Shop/34740/
# 2025-05-01 14:09:59,706 INFO: Saved shop id=355
# 2025-05-01 14:10:00,707 INFO: Processing shop: https://emalls.ir/Shop/43104/
# 2025-05-01 14:10:02,280 INFO: Saved shop id=356
# 2025-05-01 14:10:03,281 INFO: Processing shop: https://emalls.ir/Shop/23292/
# 2025-05-01 14:10:04,411 INFO: Saved shop id=357
# 2025-05-01 14:10:05,413 INFO: Processing shop: https://emalls.ir/Shop/23423/
# 2025-05-01 14:10:08,971 INFO: Saved shop id=358
# 2025-05-01 14:10:09,972 INFO: Processing shop: https://emalls.ir/Shop/3942/
# 2025-05-01 14:10:10,750 INFO: Saved shop id=359
# 2025-05-01 14:10:11,751 INFO: Processing shop: https://emalls.ir/Shop/54095/
# 2025-05-01 14:10:12,849 INFO: Saved shop id=360
# 2025-05-01 14:10:13,850 INFO: Processing shop: https://emalls.ir/Shop/3595/
# 2025-05-01 14:10:14,710 INFO: Saved shop id=361
# 2025-05-01 14:10:15,711 INFO: Processing shop: https://emalls.ir/Shop/20784/
# 2025-05-01 14:10:17,239 INFO: Saved shop id=362
# 2025-05-01 14:10:18,241 INFO: Processing shop: https://emalls.ir/Shop/3533/
# 2025-05-01 14:10:19,559 INFO: Saved shop id=363
# 2025-05-01 14:10:20,560 INFO: Processing shop: https://emalls.ir/Shop/22831/
# 2025-05-01 14:10:23,170 INFO: Saved shop id=364
# 2025-05-01 14:10:24,172 INFO: Processing shop: https://emalls.ir/Shop/24375/
# 2025-05-01 14:10:25,922 INFO: Saved shop id=365
# 2025-05-01 14:10:26,923 INFO: Processing shop: https://emalls.ir/Shop/982/
# 2025-05-01 14:10:28,713 INFO: Saved shop id=366
# 2025-05-01 14:10:29,714 INFO: Processing shop: https://emalls.ir/Shop/6884/
# 2025-05-01 14:10:31,553 INFO: Saved shop id=367
# 2025-05-01 14:10:32,554 INFO: Processing shop: https://emalls.ir/Shop/4550/
# 2025-05-01 14:10:35,251 INFO: Saved shop id=368
# 2025-05-01 14:10:36,253 INFO: Processing shop: https://emalls.ir/Shop/37944/
# 2025-05-01 14:10:37,849 INFO: Saved shop id=369
# 2025-05-01 14:10:38,850 INFO: Processing shop: https://emalls.ir/Shop/4058/
# 2025-05-01 14:10:40,149 INFO: Saved shop id=370
# 2025-05-01 14:10:41,150 INFO: Processing shop: https://emalls.ir/Shop/35570/
# 2025-05-01 14:10:42,259 INFO: Saved shop id=371
# 2025-05-01 14:10:43,260 INFO: Processing shop: https://emalls.ir/Shop/20170/
# 2025-05-01 14:10:43,707 INFO: Saved shop id=372
# 2025-05-01 14:10:44,708 INFO: Processing shop: https://emalls.ir/Shop/21758/
# 2025-05-01 14:10:45,794 INFO: Saved shop id=373
# 2025-05-01 14:10:46,795 INFO: Processing shop: https://emalls.ir/Shop/36107/
# 2025-05-01 14:10:48,199 INFO: Saved shop id=374
# 2025-05-01 14:10:49,200 INFO: Processing shop: https://emalls.ir/Shop/31422/
# 2025-05-01 14:10:51,309 INFO: Saved shop id=375
# 2025-05-01 14:10:52,310 INFO: Processing shop: https://emalls.ir/Shop/20443/
# 2025-05-01 14:10:52,899 INFO: Saved shop id=376
# 2025-05-01 14:10:53,901 INFO: Processing shop: https://emalls.ir/Shop/43354/
# 2025-05-01 14:10:55,037 INFO: Saved shop id=377
# 2025-05-01 14:10:56,038 INFO: Processing shop: https://emalls.ir/Shop/4433/
# 2025-05-01 14:10:57,560 INFO: Saved shop id=378
# 2025-05-01 14:10:58,561 INFO: Processing shop: https://emalls.ir/Shop/4394/
# 2025-05-01 14:11:00,325 INFO: Saved shop id=379
# 2025-05-01 14:11:01,326 INFO: Processing shop: https://emalls.ir/Shop/20095/
# 2025-05-01 14:11:02,334 INFO: Saved shop id=380
# 2025-05-01 14:11:03,335 INFO: Processing shop: https://emalls.ir/Shop/3278/
# 2025-05-01 14:11:04,410 INFO: Saved shop id=381
# 2025-05-01 14:11:05,411 INFO: Processing shop: https://emalls.ir/Shop/5980/
# 2025-05-01 14:11:07,329 INFO: Saved shop id=382
# 2025-05-01 14:11:08,330 INFO: Processing shop: https://emalls.ir/Shop/39320/
# 2025-05-01 14:11:10,251 INFO: Saved shop id=383
# 2025-05-01 14:11:11,252 INFO: Processing shop: https://emalls.ir/Shop/43354/
# 2025-05-01 14:11:11,777 INFO: Saved shop id=377
# 2025-05-01 14:11:12,778 INFO: Processing shop: https://emalls.ir/Shop/39320/
# 2025-05-01 14:11:13,224 INFO: Saved shop id=383
# 2025-05-01 14:11:14,225 INFO: Processing shop: https://emalls.ir/Shop/715/
# 2025-05-01 14:11:16,526 INFO: Saved shop id=386
# 2025-05-01 14:11:17,528 INFO: Processing shop: https://emalls.ir/Shop/5212/
# 2025-05-01 14:11:18,982 INFO: Saved shop id=387
# 2025-05-01 14:11:19,984 INFO: Processing shop: https://emalls.ir/Shop/6773/
# 2025-05-01 14:11:22,527 INFO: Saved shop id=388
# 2025-05-01 14:11:23,528 INFO: Processing shop: https://emalls.ir/Shop/555/
# 2025-05-01 14:11:24,791 INFO: Saved shop id=389
# 2025-05-01 14:11:25,792 INFO: Processing shop: https://emalls.ir/Shop/2377/
# 2025-05-01 14:11:27,061 INFO: Saved shop id=390
# 2025-05-01 14:11:28,062 INFO: Processing shop: https://emalls.ir/Shop/744/
# 2025-05-01 14:11:30,311 INFO: Saved shop id=391
# 2025-05-01 14:11:31,312 INFO: Processing shop: https://emalls.ir/Shop/1279/
# 2025-05-01 14:11:32,773 INFO: Saved shop id=392
# 2025-05-01 14:11:33,774 INFO: Processing shop: https://emalls.ir/Shop/6831/
# 2025-05-01 14:11:34,687 INFO: Saved shop id=393
# 2025-05-01 14:11:35,688 INFO: Processing shop: https://emalls.ir/Shop/2761/
# 2025-05-01 14:11:37,384 INFO: Saved shop id=394
# 2025-05-01 14:11:38,385 INFO: Processing shop: https://emalls.ir/Shop/24798/
# 2025-05-01 14:11:39,971 INFO: Saved shop id=395
# 2025-05-01 14:11:40,973 INFO: Processing shop: https://emalls.ir/Shop/2620/
# 2025-05-01 14:11:42,960 INFO: Saved shop id=396
# 2025-05-01 14:11:43,960 INFO: Processing shop: https://emalls.ir/Shop/18525/
# 2025-05-01 14:11:46,038 INFO: Saved shop id=397
# 2025-05-01 14:11:47,039 INFO: Processing shop: https://emalls.ir/Shop/19451/
# 2025-05-01 14:11:49,841 INFO: Saved shop id=398
# 2025-05-01 14:11:50,843 INFO: Processing shop: https://emalls.ir/Shop/650/
# 2025-05-01 14:11:53,003 INFO: Saved shop id=399
# 2025-05-01 14:11:54,004 INFO: Processing shop: https://emalls.ir/Shop/31511/
# 2025-05-01 14:11:56,038 INFO: Saved shop id=400
# 2025-05-01 14:11:57,039 INFO: Processing shop: https://emalls.ir/Shop/4931/
# 2025-05-01 14:11:58,813 INFO: Saved shop id=401
# 2025-05-01 14:11:59,814 INFO: Processing shop: https://emalls.ir/Shop/569/
# 2025-05-01 14:12:03,114 INFO: Saved shop id=402
# 2025-05-01 14:12:04,116 INFO: Processing shop: https://emalls.ir/Shop/22795/
# 2025-05-01 14:12:04,819 INFO: Saved shop id=403
# 2025-05-01 14:12:05,820 INFO: Processing shop: https://emalls.ir/Shop/56272/
# 2025-05-01 14:12:06,914 INFO: Saved shop id=404
# 2025-05-01 14:12:07,916 INFO: Processing shop: https://emalls.ir/Shop/3793/
# 2025-05-01 14:12:10,028 INFO: Saved shop id=405
# 2025-05-01 14:12:11,030 INFO: Processing shop: https://emalls.ir/Shop/1115/
# 2025-05-01 14:12:14,602 INFO: Saved shop id=406
# 2025-05-01 14:12:15,603 INFO: Processing shop: https://emalls.ir/Shop/23516/
# 2025-05-01 14:12:18,073 INFO: Saved shop id=407
# 2025-05-01 14:12:19,075 INFO: Processing shop: https://emalls.ir/Shop/2970/
# 2025-05-01 14:12:21,562 INFO: Saved shop id=408
# 2025-05-01 14:12:22,564 INFO: Processing shop: https://emalls.ir/Shop/20240/
# 2025-05-01 14:12:24,939 INFO: Saved shop id=409
# 2025-05-01 14:12:25,939 INFO: Processing shop: https://emalls.ir/Shop/2070/
# 2025-05-01 14:12:28,243 INFO: Saved shop id=410
# 2025-05-01 14:12:29,245 INFO: Processing shop: https://emalls.ir/Shop/784/
# 2025-05-01 14:12:31,233 INFO: Saved shop id=411
# 2025-05-01 14:12:32,235 INFO: Processing shop: https://emalls.ir/Shop/728/
# 2025-05-01 14:12:33,138 INFO: Saved shop id=412
# 2025-05-01 14:12:34,139 INFO: Processing shop: https://emalls.ir/Shop/19124/
# 2025-05-01 14:12:35,495 INFO: Saved shop id=413
# 2025-05-01 14:12:36,497 INFO: Processing shop: https://emalls.ir/Shop/23073/
# 2025-05-01 14:12:38,028 INFO: Saved shop id=414
# 2025-05-01 14:12:39,029 INFO: Processing shop: https://emalls.ir/Shop/25687/
# 2025-05-01 14:12:40,748 INFO: Saved shop id=415
# 2025-05-01 14:12:41,749 INFO: Processing shop: https://emalls.ir/Shop/18596/
# 2025-05-01 14:12:42,631 INFO: Saved shop id=416
# 2025-05-01 14:12:43,632 INFO: Processing shop: https://emalls.ir/Shop/2936/
# 2025-05-01 14:12:44,665 INFO: Saved shop id=417
# 2025-05-01 14:12:45,666 INFO: Processing shop: https://emalls.ir/Shop/2511/
# 2025-05-01 14:12:47,931 INFO: Saved shop id=418
# 2025-05-01 14:12:48,932 INFO: Processing shop: https://emalls.ir/Shop/602/
# 2025-05-01 14:12:50,718 INFO: Saved shop id=419
# 2025-05-01 14:12:51,719 INFO: Processing shop: https://emalls.ir/Shop/5523/
# 2025-05-01 14:12:53,072 INFO: Saved shop id=420
# 2025-05-01 14:12:54,073 INFO: Processing shop: https://emalls.ir/Shop/25436/
# 2025-05-01 14:12:55,322 INFO: Saved shop id=421
# 2025-05-01 14:12:56,323 INFO: Processing shop: https://emalls.ir/Shop/5699/
# 2025-05-01 14:12:57,368 INFO: Saved shop id=422
# 2025-05-01 14:12:58,369 INFO: Processing shop: https://emalls.ir/Shop/2468/
# 2025-05-01 14:12:59,587 INFO: Saved shop id=423
# 2025-05-01 14:13:00,588 INFO: Processing shop: https://emalls.ir/Shop/49841/
# 2025-05-01 14:13:01,791 INFO: Saved shop id=424
# 2025-05-01 14:13:02,792 INFO: Processing shop: https://emalls.ir/Shop/2355/
# 2025-05-01 14:13:04,514 INFO: Saved shop id=425
# 2025-05-01 14:13:05,515 INFO: Processing shop: https://emalls.ir/Shop/1132/
# 2025-05-01 14:13:06,413 INFO: Saved shop id=426
# 2025-05-01 14:13:07,414 INFO: Processing shop: https://emalls.ir/Shop/4108/
# 2025-05-01 14:13:09,000 INFO: Saved shop id=427
# 2025-05-01 14:13:10,001 INFO: Processing shop: https://emalls.ir/Shop/2211/
# 2025-05-01 14:13:11,403 INFO: Saved shop id=428
# 2025-05-01 14:13:12,404 INFO: Processing shop: https://emalls.ir/Shop/1757/
# 2025-05-01 14:13:13,705 INFO: Saved shop id=429
# 2025-05-01 14:13:14,707 INFO: Processing shop: https://emalls.ir/Shop/2843/
# 2025-05-01 14:13:17,085 INFO: Saved shop id=430
# 2025-05-01 14:13:18,086 INFO: Processing shop: https://emalls.ir/Shop/4359/
# 2025-05-01 14:13:21,199 INFO: Saved shop id=431
# 2025-05-01 14:13:22,200 INFO: Processing shop: https://emalls.ir/Shop/25768/
# 2025-05-01 14:13:24,286 INFO: Saved shop id=432
# 2025-05-01 14:13:25,288 INFO: Processing shop: https://emalls.ir/Shop/37300/
# 2025-05-01 14:13:26,655 INFO: Saved shop id=433
# 2025-05-01 14:13:27,656 INFO: Processing shop: https://emalls.ir/Shop/684/
# 2025-05-01 14:13:29,409 INFO: Saved shop id=434
# 2025-05-01 14:13:30,410 INFO: Processing shop: https://emalls.ir/Shop/4444/
# 2025-05-01 14:13:31,411 INFO: Saved shop id=435
# 2025-05-01 14:13:32,412 INFO: Processing shop: https://emalls.ir/Shop/697/
# 2025-05-01 14:13:33,446 INFO: Saved shop id=436
# 2025-05-01 14:13:34,447 INFO: Processing shop: https://emalls.ir/Shop/1819/
# 2025-05-01 14:13:34,923 INFO: Saved shop id=437
# 2025-05-01 14:13:35,924 INFO: Processing shop: https://emalls.ir/Shop/5887/
# 2025-05-01 14:13:37,971 INFO: Saved shop id=438
# 2025-05-01 14:13:38,972 INFO: Processing shop: https://emalls.ir/Shop/7293/
# 2025-05-01 14:13:41,216 INFO: Saved shop id=439
# 2025-05-01 14:13:42,217 INFO: Processing shop: https://emalls.ir/Shop/26709/
# 2025-05-01 14:13:43,231 INFO: Saved shop id=440
# 2025-05-01 14:13:44,232 INFO: Processing shop: https://emalls.ir/Shop/19493/
# 2025-05-01 14:13:45,604 INFO: Saved shop id=441
# 2025-05-01 14:13:46,605 INFO: Processing shop: https://emalls.ir/Shop/5943/
# 2025-05-01 14:13:47,074 INFO: Saved shop id=442
# 2025-05-01 14:13:48,076 INFO: Processing shop: https://emalls.ir/Shop/3008/
# 2025-05-01 14:13:49,321 INFO: Saved shop id=443
# 2025-05-01 14:13:50,322 INFO: Processing shop: https://emalls.ir/Shop/1539/
# 2025-05-01 14:13:52,162 INFO: Saved shop id=444
# 2025-05-01 14:13:53,163 INFO: Processing shop: https://emalls.ir/Shop/4514/
# 2025-05-01 14:13:58,697 INFO: Saved shop id=445
# 2025-05-01 14:13:59,698 INFO: Processing shop: https://emalls.ir/Shop/28585/
# 2025-05-01 14:14:00,609 INFO: Saved shop id=446
# 2025-05-01 14:14:01,610 INFO: Processing shop: https://emalls.ir/Shop/880/
# 2025-05-01 14:14:02,849 INFO: Saved shop id=447
# 2025-05-01 14:14:03,851 INFO: Processing shop: https://emalls.ir/Shop/27622/
# 2025-05-01 14:14:05,335 INFO: Saved shop id=448
# 2025-05-01 14:14:06,336 INFO: Processing shop: https://emalls.ir/Shop/4307/
# 2025-05-01 14:14:07,417 INFO: Saved shop id=449
# 2025-05-01 14:14:08,418 INFO: Processing shop: https://emalls.ir/Shop/2707/
# 2025-05-01 14:14:09,824 INFO: Saved shop id=450
# 2025-05-01 14:14:10,825 INFO: Processing shop: https://emalls.ir/Shop/4203/
# 2025-05-01 14:14:12,545 INFO: Saved shop id=451
# 2025-05-01 14:14:13,546 INFO: Processing shop: https://emalls.ir/Shop/1927/
# 2025-05-01 14:14:15,350 INFO: Saved shop id=452
# 2025-05-01 14:14:16,351 INFO: Processing shop: https://emalls.ir/Shop/19709/
# 2025-05-01 14:14:18,300 INFO: Saved shop id=453
# 2025-05-01 14:14:19,301 INFO: Processing shop: https://emalls.ir/Shop/1063/
# 2025-05-01 14:14:21,290 INFO: Saved shop id=454
# 2025-05-01 14:14:22,291 INFO: Processing shop: https://emalls.ir/Shop/21351/
# 2025-05-01 14:14:23,935 INFO: Saved shop id=455
# 2025-05-01 14:14:24,937 INFO: Processing shop: https://emalls.ir/Shop/38922/
# 2025-05-01 14:14:26,361 INFO: Saved shop id=456
# 2025-05-01 14:14:27,363 INFO: Processing shop: https://emalls.ir/Shop/46775/
# 2025-05-01 14:14:28,387 INFO: Saved shop id=457
# 2025-05-01 14:14:29,389 INFO: Processing shop: https://emalls.ir/Shop/2207/
# 2025-05-01 14:14:30,416 INFO: Saved shop id=458
# 2025-05-01 14:14:31,417 INFO: Processing shop: https://emalls.ir/Shop/3315/
# 2025-05-01 14:14:34,656 INFO: Saved shop id=459
# 2025-05-01 14:14:35,657 INFO: Processing shop: https://emalls.ir/Shop/5311/
# 2025-05-01 14:14:37,001 INFO: Saved shop id=460
# 2025-05-01 14:14:38,003 INFO: Processing shop: https://emalls.ir/Shop/544/
# 2025-05-01 14:14:40,900 INFO: Saved shop id=461
# 2025-05-01 14:14:41,902 INFO: Processing shop: https://emalls.ir/Shop/24653/
# 2025-05-01 14:14:43,688 INFO: Saved shop id=462
# 2025-05-01 14:14:44,689 INFO: Processing shop: https://emalls.ir/Shop/35880/
# 2025-05-01 14:14:45,568 INFO: Saved shop id=463
# 2025-05-01 14:14:46,568 INFO: Processing shop: https://emalls.ir/Shop/4456/
# 2025-05-01 14:14:48,496 INFO: Saved shop id=464
# 2025-05-01 14:14:49,498 INFO: Processing shop: https://emalls.ir/Shop/1798/
# 2025-05-01 14:14:51,429 INFO: Saved shop id=465
# 2025-05-01 14:14:52,430 INFO: Processing shop: https://emalls.ir/Shop/161/
# 2025-05-01 14:14:56,451 INFO: Saved shop id=466
# 2025-05-01 14:14:57,452 INFO: Processing shop: https://emalls.ir/Shop/35879/
# 2025-05-01 14:14:58,756 INFO: Saved shop id=467
# 2025-05-01 14:14:59,757 INFO: Processing shop: https://emalls.ir/Shop/5776/
# 2025-05-01 14:15:01,125 INFO: Saved shop id=468
# 2025-05-01 14:15:02,126 INFO: Processing shop: https://emalls.ir/Shop/18749/
# 2025-05-01 14:15:05,709 INFO: Saved shop id=469
# 2025-05-01 14:15:06,710 INFO: Processing shop: https://emalls.ir/Shop/19847/
# 2025-05-01 14:15:12,200 INFO: Saved shop id=470
# 2025-05-01 14:15:13,201 INFO: Processing shop: https://emalls.ir/Shop/24028/
# 2025-05-01 14:15:14,583 INFO: Saved shop id=471
# 2025-05-01 14:15:15,584 INFO: Processing shop: https://emalls.ir/Shop/26223/
# 2025-05-01 14:15:17,483 INFO: Saved shop id=472
# 2025-05-01 14:15:18,485 INFO: Processing shop: https://emalls.ir/Shop/906/
# 2025-05-01 14:15:20,065 INFO: Saved shop id=473
# 2025-05-01 14:15:21,066 INFO: Processing shop: https://emalls.ir/Shop/18707/
# 2025-05-01 14:15:23,074 INFO: Saved shop id=474
# 2025-05-01 14:15:24,076 INFO: Processing shop: https://emalls.ir/Shop/5706/
# 2025-05-01 14:15:25,253 INFO: Saved shop id=475
# 2025-05-01 14:15:26,255 INFO: Processing shop: https://emalls.ir/Shop/28038/
# 2025-05-01 14:15:27,909 INFO: Saved shop id=476
# 2025-05-01 14:15:28,911 INFO: Processing shop: https://emalls.ir/Shop/38535/
# 2025-05-01 14:15:29,986 INFO: Saved shop id=477
# 2025-05-01 14:15:30,987 INFO: Processing shop: https://emalls.ir/Shop/49128/
# 2025-05-01 14:15:32,233 INFO: Saved shop id=478
# 2025-05-01 14:15:33,235 INFO: Processing shop: https://emalls.ir/Shop/2920/
# 2025-05-01 14:15:34,681 INFO: Saved shop id=479
# 2025-05-01 14:15:35,683 INFO: Scraping complete

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

DB_CONFIG = {
    'dbname':   os.getenv('EMALLS_DB', 'emalls_db'),
    'user':     os.getenv('EMALLS_USER','mahla'),
    'password': os.getenv('EMALLS_PW','1234'),
    'host':     os.getenv('EMALLS_HOST','localhost'),
    'port':     os.getenv('EMALLS_PORT','5432'),
}

# Construct the SQLAlchemy connection string
string_connection = (
    f"postgresql://{DB_CONFIG['user']}:{DB_CONFIG['password']}"
    f"@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['dbname']}"
)

# Create the engine and read the table
engine = create_engine(string_connection)
query = 'SELECT * FROM emalls_shops;'
result = pd.read_sql(query, engine)

# %%
result.shape
# Out:
# (478, 9)

# %%
import re
import time
from bs4 import BeautifulSoup

FAILED_LOG = 'failed_shops.log'
REQUEST_DELAY = 1  # match your existing delay

def retry_failed_urls(conn, session):
    """
    Read URLs from FAILED_LOG, clear the log, then re‐fetch & insert them.
    """
    # 1) Read and extract URLs
    try:
        with open(FAILED_LOG, 'r', encoding='utf-8') as f:
            lines = f.readlines()
    except FileNotFoundError:
        return  # nothing to retry

    urls = set()
    for line in lines:
        # assume each line ends with the URL
        m = re.search(r'(https?://\S+)$', line.strip())
        if m:
            urls.add(m.group(1))

    if not urls:
        return

    # 2) Clear the failed log before retrying
    open(FAILED_LOG, 'w').close()

    # 3) Retry each URL
    for url in urls:
        logger.info(f"Retrying failed URL: {url}")
        try:
            resp = session.get(url, timeout=5)
        except requests.exceptions.RequestException as e:
            logger.error(f"Retry request failed: {e}")
            failed_logger.info(url)
            continue

        if not resp.ok:
            logger.error(f"Retry returned {resp.status_code} for {url}")
            failed_logger.info(url)
            continue

        # 4) Parse & insert
        soup = BeautifulSoup(resp.text, 'html.parser')
        info = extract_shop_info(soup, url)
        shop_id = insert_shop(conn, info)
        if not shop_id:
            logger.warning(f"Retry failed to save shop: {url}")
            failed_logger.info(url)
        else:
            logger.info(f"Retry saved shop id={shop_id}")

        time.sleep(REQUEST_DELAY)

# …inside your main(), after the initial crawl and insert loop:
conn = psycopg2.connect(**DB_CONFIG)
session = requests.Session()
retry_failed_urls(conn, session)
